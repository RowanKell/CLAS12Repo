# %%
from ROOT import TFile,TTree,TCanvas,TH1F, gStyle, TLatex, gPad, TLegend, TLorentzVector, TH2F, TLine, TF1, TBox, RDataFrame, TPad, TF2, TStyle
import ROOT
import numpy as np
# Out:
# Welcome to JupyROOT 6.22/06

# %%
gStyle.SetOptStat(0)
gStyle.SetHistLineWidth(2)
gStyle.SetTitleXSize(0.045)
gStyle.SetTitleYSize(0.035)
gStyle.SetTitleYOffset(1.55)
gStyle.SetPalette(55)
gStyle.SetNumberContours(50)

latex=TLatex()
latex.SetTextSize(0.03)

biglatex=TLatex()
biglatex.SetTextSize(0.045)

smalllatex=TLatex()
smalllatex.SetTextSize(0.022)

# %%
d = RDataFrame("tree_postprocess"
                , {
#                     "../../../data/June_9/spring2019/june9_*.root"
#                    ,
#                     "../../../data/June_9/fall2018_plus/june9_*.root"
#                    ,
                     "../../../data/June_9/fall2018_minusfinal/june9_*.root"
#                     "../../../data/June_9/fall2018_minusPhi_h/june9_*.root"
#                     "../../../data/June_8/fall2018_minus_xFindicut/june8_*.root"
#                     "../../../data/June_8/fall2018_minus_xFmanualcut/june8_*.root" # pretty good data, but has dihadron xF cut instead of individual xF cuts for each pion
#                    "../../../data/June_8/fall2018_minus2/june8_*.root" 
#                ,
#                    "../../../data/June_7_FullKinematics/fall2018_plus/june7_*.root"
#                ,
#                    "../../../data/June_7_FullKinematics/spring2019/june7_*.root"
                  })
d1 = RDataFrame("tree_postprocess",
                {
                     "../../../data/June_9/spring2019/june9_*.root"
                    ,
                     "../../../data/June_9/fall2018_plus/june9_*.root"
                    ,
                     "../../../data/June_9/fall2018_minusfinal/june9_*.root"
                })

# %%
w = 900 #width
h = 700 #height
xFcut = "xF_piplus > 0 && xF_piminus > 0" # used for manual dihadron xF cut after postprocessing

# %%
#Histo Size in Prez:
#Width: 8.32
#Height: 6.24

h0 = d.Filter("M_x > 1.5").Histo1D(("h0",";xF piplus;Counts",1000,-1,1),"xF_piplus")
h13 = d.Filter("M_x > 1.5").Histo1D(("h13",";xF piminus;Counts",1000,-1,1),"xF_piminus")
h1 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h1",";x;Counts",1000,0,1),"x")
h2 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h2",";y;Counts",1000,0,1),"y")
h3 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h3",";Q^{2};Counts",1000,0,8),"Q2")
h4 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h4",";z_{h};Counts",1000,0,1),"z_h")
h5 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h5",";x_{F};Counts",1000,-1,1),"x_F")
h6 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h6",";P_{h}^{#perp};Counts",1000,0,2),"P_h")
h7 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h7",";M_{x} (GeV);Counts",1000,0.5,3),"M_x")
h8 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h8",";#theta;Counts",1000,0,3.14),"th")
h9 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h9",";#phi_{R#perp};Counts",1000,0,6.3),"phi_R")
h10 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h10",";#phi_{h};Counts",1000,0,6.3),"phi_h")
h11 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h11",";M_{h} (GeV);Counts",1000,0,2),"Mdihadron")
h12 = d.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h12",";W (GeV);Counts",1000,0,5),"W")

# %%
ht1 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h1",";x;Counts",1000,0,1),"x")
ht2 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h2",";y;Counts",1000,0,1),"y")
ht3 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h3",";Q^{2};Counts",1000,0,8),"Q2")
ht4 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h4",";z_{h};Counts",1000,0,1),"z_h")
ht5 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h5",";x_{F};Counts",1000,-1,1),"x_F")
ht6 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h6",";P_{h}^{#perp};Counts",1000,0,2),"P_h")
ht7 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h7",";M_{x} (GeV);Counts",1000,0.5,3),"M_x")
ht8 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h8",";#theta;Counts",1000,0,3.14),"th")
ht9 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h9",";#phi_{R#perp};Counts",1000,0,6.3),"phi_R")
ht10 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h10",";#phi_{h};Counts",1000,0,6.3),"phi_h")
ht11 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h11",";M_{h} (GeV);Counts",1000,0,2),"Mdihadron")
ht12 = d1.Filter("M_x > 1.5").Filter(xFcut).Histo1D(("h12",";W (GeV);Counts",1000,0,5),"W")

# %%
hist1 = ht1.GetValue()
hist1.Scale(1.0 / hist.Integral())
hist2 = ht2.GetValue()
hist2.Scale(1.0 / hist.Integral())
hist3 = ht3.GetValue()
hist3.Scale(1.0 / hist.Integral())
hist4 = ht4.GetValue()
hist4.Scale(1.0 / hist.Integral())
hist5 = ht5.GetValue()
hist5.Scale(1.0 / hist.Integral())
hist6 = ht6.GetValue()
hist6.Scale(1.0 / hist.Integral())
hist7 = ht7.GetValue()
hist7.Scale(1.0 / hist.Integral())
hist8 = ht8.GetValue()
hist8.Scale(1.0 / hist.Integral())
hist9 = ht9.GetValue()
hist9.Scale(1.0 / hist.Integral())
hist10 = ht10.GetValue()
hist10.Scale(1.0 / hist.Integral())
hist11 = ht11.GetValue()
hist11.Scale(1.0 / hist.Integral())
hist12 = ht12.GetValue()
hist12.Scale(1.0 / hist.Integral())

# %%
c = TCanvas("c","c",w,h)
histo1 = h1.GetValue()
histo1.Scale(1.0 / histo1.Integral())
histo1.SetLineColor(1)


hist1 = ht1.GetValue()
hist1.Scale(1.0 / hist1.Integral())
hist1.SetLineColor(2)

hist1.Draw("hist")
histo1.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist1,"Combined","l")
legend.AddEntry(histo1,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo2 = h2.GetValue()
histo2.Scale(1.0 / histo2.Integral())
histo2.SetLineColor(1)


hist2 = ht2.GetValue()
hist2.Scale(1.0 / hist2.Integral())
hist2.SetLineColor(2)

histo2.Draw("hist")
hist2.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist2,"Combined","l")
legend.AddEntry(histo2,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo3 = h3.GetValue()
histo3.Scale(1.0 / histo3.Integral())
histo3.SetLineColor(1)


hist3 = ht3.GetValue()
hist3.Scale(1.0 / hist3.Integral())
hist3.SetLineColor(2)

histo3.Draw("hist")
hist3.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist3,"Combined","l")
legend.AddEntry(histo3,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo4 = h4.GetValue()
histo4.Scale(1.0 / histo4.Integral())
histo4.SetLineColor(1)


hist4 = ht4.GetValue()
hist4.Scale(1.0 / hist4.Integral())
hist4.SetLineColor(2)

histo4.Draw("hist")
hist4.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist4,"Combined","l")
legend.AddEntry(histo4,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo5 = h5.GetValue()
histo5.Scale(1.0 / histo5.Integral())
histo5.SetLineColor(1)


hist5 = ht5.GetValue()
hist5.Scale(1.0 / hist5.Integral())
hist5.SetLineColor(2)

histo5.Draw("hist")
hist5.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist5,"Combined","l")
legend.AddEntry(histo5,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo6 = h6.GetValue()
histo6.Scale(1.0 / histo6.Integral())
histo6.SetLineColor(1)


hist6 = ht6.GetValue()
hist6.Scale(1.0 / hist6.Integral())
hist6.SetLineColor(2)

histo6.Draw("hist")
hist6.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist6,"Combined","l")
legend.AddEntry(histo6,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo7 = h7.GetValue()
histo7.Scale(1.0 / histo7.Integral())
histo7.SetLineColor(1)


hist7 = ht7.GetValue()
hist7.Scale(1.0 / hist7.Integral())
hist7.SetLineColor(2)

histo7.Draw("hist")
hist7.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist7,"Combined","l")
legend.AddEntry(histo7,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo8 = h8.GetValue()
histo8.Scale(1.0 / histo8.Integral())
histo8.SetLineColor(1)


hist8 = ht8.GetValue()
hist8.Scale(1.0 / hist8.Integral())
hist8.SetLineColor(2)

histo8.Draw("hist")
hist8.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist8,"Combined","l")
legend.AddEntry(histo8,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo9 = h9.GetValue()
histo9.Scale(1.0 / histo9.Integral())
histo9.SetLineColor(1)


hist9 = ht9.GetValue()
hist9.Scale(1.0 / hist9.Integral())
hist9.SetLineColor(2)

histo9.Draw("hist")
hist9.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist9,"Combined","l")
legend.AddEntry(histo9,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo10 = h10.GetValue()
histo10.Scale(1.0 / histo10.Integral())
histo10.SetLineColor(1)


hist10 = ht10.GetValue()
hist10.Scale(1.0 / hist10.Integral())
hist10.SetLineColor(2)

histo10.Draw("hist")
hist10.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist10,"Combined","l")
legend.AddEntry(histo10,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo11 = h11.GetValue()
histo11.Scale(1.0 / histo11.Integral())
histo11.SetLineColor(1)


hist11 = ht11.GetValue()
hist11.Scale(1.0 / hist11.Integral())
hist11.SetLineColor(2)

histo11.Draw("hist")
hist11.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist11,"Combined","l")
legend.AddEntry(histo11,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
histo12 = h12.GetValue()
histo12.Scale(1.0 / histo12.Integral())
histo12.SetLineColor(1)


hist12 = ht12.GetValue()
hist12.Scale(1.0 / hist12.Integral())
hist12.SetLineColor(2)

histo12.Draw("hist")
hist12.Draw("hist same")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

legend=TLegend(0.65,0.17,0.8,0.27)
legend.AddEntry(hist12,"Combined","l")
legend.AddEntry(histo12,"Fall 2018 (-)","l")
legend.Draw("same")

c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
h0.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")
c.SetGrid()
c.Draw()

# %%
c = TCanvas("c","c",w,h)
h13.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")
c.SetGrid()
c.Draw()
