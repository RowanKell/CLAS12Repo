# %%
from ROOT import TFile,TTree,TCanvas,TH1F, gStyle, TLatex, gPad, TLegend, TLorentzVector, TH2F, TLine, TF1, TBox, RDataFrame, TPad, TF2, TStyle
import ROOT
import numpy as np
# Out:
# Welcome to JupyROOT 6.22/06

# %%
gStyle.SetOptStat(0)
gStyle.SetHistLineWidth(2)
gStyle.SetTitleXSize(0.045)
gStyle.SetTitleYSize(0.035)
gStyle.SetTitleYOffset(1.5)
gStyle.SetPalette(55)
gStyle.SetNumberContours(50)

latex=TLatex()
latex.SetTextSize(0.03)

biglatex=TLatex()
biglatex.SetTextSize(0.045)

smalllatex=TLatex()
smalllatex.SetTextSize(0.022)

# %% [markdown]
# Create an RDataFrame by importing the root files from the analysis

# %%
d1 = RDataFrame("tree_postprocess"
                , {
                    "../../../data/June_7_data/fall2018minus/june7_*.root" 
                ,
                    "../../../data/June_7_data/fall2018plus/june7_*.root"
                ,
                    "../../../data/June_7_data/spring2019/june7_*"
                  })
d2 = RDataFrame("tree_postprocess", "../../../data/June_7_data/missingmassminus/june7_*.root")

# %%
h1 = d1.Filter("Mdihadron < 1.5").Histo2D(("h",";z_{h};M_{h}",1000,0,1.5,1000,0,2),"z_h","Mdihadron")
h2 = d1.Filter("Mdihadron < 1.5").Histo2D(("h",";z_{h};y",1000,0,1.5,1000,0,1),"z_h","y")
h3 = d1.Filter("Mdihadron < 1.5").Histo2D(("h",";z_{h};Q^{2}",1000,0,1.5,1000,0,8),"z_h","Q2")
h4 = d1.Filter("Mdihadron < 1.5").Histo2D(("h",";z_{h};W",1000,0,1.5,1000,0,5),"z_h","W")
h5 = d1.Filter("Mdihadron < 1.5").Histo2D(("h",";z_{h};x",1000,0,1.5,1000,0,1),"z_h","x")
h6 = d1.Filter("Mdihadron < 1.5").Histo1D(("h",";z_{h};Counts",1000,0,1.5),"z_h")

# %%
c = TCanvas("c","c",800,600)
#default = TStyle("Default","Default Style")

#h1.SetLineColor(1)
h1.Draw("colz")
#smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h2.Draw("colz")
#smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h3.Draw("colz")
#smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h4.Draw("colz")
#smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h5.Draw("colz")
#smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h6.Draw()
c.Draw("hist")

# %%
h1 = d1.Histo1D(("h",";x;Counts",1000,0,1),"x")
c = TCanvas("c","c",1100,800)
#default = TStyle("Default","Default Style")

h1.SetLineColor(1)
h1.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h1 = d1.Histo1D(("h",";M_h (GeV);Counts",1000,0,2),"Mdihadron")
c = TCanvas("c","c",1100,800)
#default = TStyle("Default","Default Style")

h1.SetLineColor(1)
h1.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h1 = d1.Filter("Mdihadron<1.5").Histo1D(("h",";y;Counts",1000,0,1),"y")
c = TCanvas("c","c",1100,800)
#default = TStyle("Default","Default Style")

h1.SetLineColor(1)
h1.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h1 = d1.Histo1D(("h",";phi_R;Counts",1000,0,6),"phi_R")
c = TCanvas("c","c",1100,800)
#default = TStyle("Default","Default Style")

h1.SetLineColor(1)
h1.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h1 = d1.Histo1D(("h",";phi_h;Counts",1000,0,6),"phi_h")
c = TCanvas("c","c",1100,800)
#default = TStyle("Default","Default Style")

h1.SetLineColor(1)
h1.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
h1 = d1.Histo1D(("h",";theta;Counts",1000,0,3),"th")
c = TCanvas("c","c",1100,800)
#default = TStyle("Default","Default Style")

h1.SetLineColor(1)
h1.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/fall2018/torus+1/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# Both inbending and outbending data from fall2018 and spring2019
d2 = RDataFrame("tree_postprocess", {"../../../data/test-inbending/june6_*.root" #fall 2018 inbending data
                                     ,"../../../data/test-outbending/june6_*.root" #fall 2018 outbending data
                                     ,"../../../data/spring2019/june6_*.root" #spring2019 inbending data
                                    })

# %%
# y histogram
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";y;Counts",1000,0,1),"y")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# Q2 Histogram
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";Q^2 (GeV)^2;Counts",1000,0,8),"Q2")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# W Histogram
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";W (GeV);Counts",1000,0,5),"W")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# x Histogram
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";x;Counts",1000,0,1),"x")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# Dihadron Mass histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";M_h (GeV);Counts",1000,0,2),"Mdihadron")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# theta histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";theta;Counts",1000,0,3),"th")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
#Phi R histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";Phi_R;Counts",1000,0,6.2),"phi_R")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# Phi h histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";Phi_h;Counts",1000,0,6.2),"phi_h")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# Feynman X histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";x_F;Counts",1000,0,10),"x_F")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
#P_h histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";P_h;Counts",1000,0,1),"P_h")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# zpair histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";zpair;Counts",1000,0,1),"zpair")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()

# %%
# Missing mass histo
h2 = d2.Filter("Mdihadron < 1.5").Histo1D(("h",";y;Counts",1000,0,1),"y")
c = TCanvas("c","c",1100,800)

h2.SetLineColor(1)
h2.Draw("hist")
smalllatex.DrawLatexNDC(.12,.87,"#color[11]{/cache/clas12/rg-a/production/recon/*/torus*/pass1/v1/dst/train/nSidis//nSidis_*.hipo}")

c.Draw()
